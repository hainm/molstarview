# %%
import nglview as nv
from molstarview.widget import MolstarView

view = MolstarView()
view
# Out:
# MolstarView()

# %%
import ipywidgets

ipywidgets.Text("Hello")

# %%
import nglview as nv

nv.demo()
